# %%
def get_tuple():
    return(404,"error")

# %% [markdown]
# tuple 建立後不可以改變內容

# %%
# tuple拆解法
(code, message)=get_tuple()
print(code)
print(message)

# 1個元素的tuple
#(404,)
#
# Out:
# 404
# error

# %% [markdown]
# list 建立後可以改變內容，可新增編輯和刪除元素
# (放在list裡面的稱為元素，有索引編號，索引編號是連續的)
