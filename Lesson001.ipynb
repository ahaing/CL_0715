# %%
def get_tuple():
    return(404,"error")

# %% [markdown]
# tuple 建立後不可以改變內容

# %%
# tuple拆解法
(code, message)=get_tuple()
print(code)
print(message)

# 1個元素的tuple
#(404,)
#
# Out:
# 404
# error

# %% [markdown]
# list 建立後可以改變內容，可新增編輯和刪除元素
# (放在list裡面的稱為元素，有索引編號，索引編號是連續的)
# class list
# class list(iterable) # iterable 代表可以重複讀取

# %%
list()
# Out:
# []

# %%
list(range(1,10))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
list(('a','b',1, 2, 3))
# Out:
# ['a', 'b', 1, 2, 3]

# %%
# 符號建立
stu1 = [111, 222, 333]

for score in stu1:
    print (score)
# Out:
# 111
# 222
# 333

# %%
empty_list = []
wk_days = ['MON','TUE','WED','THU','FRI']
first_name = ['Ann', 'Brenda', 'Claire', 'Doris']
first_name
# Out:
# ['Ann', 'Brenda', 'Claire', 'Doris']

# %%
first_name[3]
# Out:
# 'Doris'

# %%
# 用 build in 的 type 查詢變數的資料類型，一定要知道每個變數的類型
type(first_name)
type(10)
type(10.0)
# Out:
# float

# %% [markdown]
# python內建的一般function直接使用
#
# But
# *list實體 => first_name
# 實體的屬性
# 實體的方法 (用點.)
# 不可以直接使用
#
# # 實體方法前面一定要用實體的名稱，查官方資料
#  (read://https_docs.python.org/?url=https%3A%2F%2Fdocs.python.org%2Fzh-tw%2F3%2Ftutorial%2Fdatastructures.html) 使用

# %%
first_name.append('Eunice')
first_name
first_name.insert(0,'ING')
first_name
# Out:
# ['ING',
#  'ING',
#  'Ann',
#  'Brenda',
#  'Claire',
#  'Doris',
#  'Eunice',
#  'Eunice',
#  'Eunice',
#  'Eunice']

# %%
# test

# %%
for word in "Hola!Testing":
    print(word)
# Out:
# H
# o
# l
# a
# !
# T
# e
# s
# t
# i
# n
# g

# %%
words = list("helloworld")
words
# Out:
# ['h', 'e', 'l', 'l', 'o', 'w', 'o', 'r', 'l', 'd']

# %%
words[-5:] # 抓後五個
# Out:
# ['w', 'o', 'r', 'l', 'd']

# %%
words[:5] # 抓前五個
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
NB=['Inc.','Private']
MOBILE=['IPhone','Samsung','Asus']
PAD=['Kindle','Kobo','Hybread']

all3c=[NB,MOBILE,PAD]
print(all3c)
print(all3c[0][0],all3c[2][2])
print(f"choose第1個為{all3c[0][0]}\nchoose第2個為{all3c[2][2]}\n")
# Out:
# [['Inc.', 'Private'], ['IPhone', 'Samsung', 'Asus'], ['Kindle', 'Kobo', 'Hybread']]
# Inc. Hybread
# choose第1個為Inc.,
# choose第2個為Hybread
