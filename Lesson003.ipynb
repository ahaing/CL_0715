# %% [markdown]
# 下載政府開放平台

# %%
filename='上櫃ESG-HR.csv'
file = open(filename, mode='r',encoding='utf-8',newline='')
# OPEN 傳出一個 file 物件

# %% [markdown]
# # 用工具箱裡面 reader 的方法
# # Reader Objects->
# csvreader.__next__()
# Return the next row of the reader’s iterable object as a list (if the object was returned from reader()) or a dict (if it is a DictReader instance), parsed according to the current Dialect. Usually you should call this as next(reader).
# __next -> iterable 可以 用 for XXX in XXX: 一個一個抓出來

# %%
import csv
csv_reader = csv.reader(file)
data_all = list(csv_reader)
for item in data_all:
    if '英濟' in item[3]:
        print(item)
for item in data_all:
    if '0.00%' in item[10]:
        print(item)
# Out:
# ['1120705', '111', '3294', '英濟', '998', '838', '779', '626', '12.70%', '0人', '0.00%']
# ['1120705', '111', '1240', '茂生農經', '835', '689', '679', '577', '10.00%', '0人', '0.00%']
# ['1120705', '111', '1259', '安心', '337', '278', '603', '548', '0.00%', '0人', '0.00%']
# ['1120705', '111', '1264', '德麥', '1077', '933', '831', '704', '11.11%', '0人', '0.00%']
# ['1120705', '111', '1569', '濱川', '1380', '1072', '692', '638', '0.00%', '0人', '0.00%']
# ['1120705', '111', '1570', '力肯', '705', '578', '542', '423', '25.00%', '0人', '0.00%']
# ['1120705', '111', '1591', '駿吉-KY', '', '', '', '', '40.00%', '0人', '0.00%']
# ['1120705', '111', '1593', '祺驊', '845', '719', '620', '475', '23.08%', '0人', '0.00%']
# ['1120705', '111', '1595', '川寶', '1216', '1050', '696', '597', '17.00%', '0人', '0.00%']
# ['1120705', '111', '1599', '宏佳騰', '726', '620', '557', '515', '29.50%', '0人', '0.00%']
# ['1120705', '111', '1742', '台蠟', '807', '686', '517', '497', '44.40%', '0人', '0.00%']
# ...

# %%
import csv
AQIname='AQI.csv'
AQI = open(AQIname, mode='r',encoding='utf-8',newline='')

AQIfile = csv.reader(AQI)
for eachline in AQIfile:
    print(eachline)
    if '板橋' in eachline[0]:
        print(eachline)
# Out:
# ['sitename', 'county', 'aqi', 'pollutant', 'status', 'so2', 'co', 'o3', 'o3_8hr', 'pm10', 'pm2.5', 'no2', 'nox', 'no', 'wind_speed', 'wind_direc', 'publishtime', 'co_8hr', 'pm2.5_avg', 'pm10_avg', 'so2_avg', 'longitude', 'latitude', 'siteid']
# ['基隆', '基隆市', '11', '', '良好', '0.6', '0.09', '16.3', '12.3', '13', '2', '1', '2.1', '1.1', '2.4', '103', '2023/07/15 15:00:00', '0.1', '2', '8', '0', '121.760056', '25.129167', '1']
# ['汐止', '新北市', '11', '', '良好', '0.6', '0.11', '12.3', '12.2', '', '1', '2.7', '5.5', '2.8', '2.4', '154', '2023/07/15 15:00:00', '0.1', '0.5', '', '0', '121.64081', '25.06624', '2']
# ['萬里', '新北市', '12', '', '良好', '0.9', '0.09', '14', '13.8', '1', '0', '0.7', '2.2', '1.5', '3', '131', '2023/07/15 15:00:00', '0', '0.8', '2', '0', '121.689881', '25.179667', '3']
# ['新店', '新北市', '14', '', '良好', '0.8', '0.06', '15.1', '15.6', '9', '0', '2.6', '4.1', '1.5', '4.4', '127', '2023/07/15 15:00:00', '0.1', '1', '9', '0', '121.537778', '24.977222', '4']
# ...

# %%
import csv
AQIname='AQI.csv'
AQI = open(AQIname, mode='r',encoding='utf-8',newline='')

AQIfile = csv.reader(AQI)
for eachline in AQIfile:
       # if not (eachline[4]=='良好'):
    if (eachline[4]!='良好'):
        print(eachline)
# Out:
# ['sitename', 'county', 'aqi', 'pollutant', 'status', 'so2', 'co', 'o3', 'o3_8hr', 'pm10', 'pm2.5', 'no2', 'nox', 'no', 'wind_speed', 'wind_direc', 'publishtime', 'co_8hr', 'pm2.5_avg', 'pm10_avg', 'so2_avg', 'longitude', 'latitude', 'siteid']
# ['桃園', '桃園市', '61', '臭氧八小時', '普通', '2.6', '0.22', '67.7', '58.4', '34', '9', '8.6', '9.6', '1', '2.2', '326', '2023/07/15 15:00:00', '0.2', '15.5', '33', '1', '121.30500531', '24.9947107', '17']
# ['平鎮', '桃園市', '54', '細懸浮微粒', '普通', '1.7', '0.28', '66', '52.3', '36', '16', '8.4', '9.8', '1.4', '2.4', '26', '2023/07/15 15:00:00', '0.2', '16.8', '34', '1', '121.203986', '24.952786', '20']
# ['龍潭', '桃園市', '53', '細懸浮微粒', '普通', '0.6', '0.27', '68', '55.5', '36', '18', '7.1', '8', '0.9', '2.4', '19', '2023/07/15 15:00:00', '0.2', '16.3', '31', '0', '121.21645772', '24.86400048', '21']
# ...
